# %% [markdown]
# (new) 서울시 구별 CCTV 갯수 및 사건 관계
# 서울시 구별 CCTV 갯수 및 사건 분석
#
# - 11_6_Analysis for crime in Seoul
#
# - 2020년 data를 수집하여 CCTV 설치와 사건 관련 분석

# %%
import numpy as np
import pandas as pd

# %%
CCTV_Seoul = pd.read_csv('data/CCTV_2020.csv', encoding='euc-kr')
CCTV_Seoul.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
CCTV_Seoul = pd.read_csv('data/CCTV_2020.csv', encoding='euc-kr')
CCTV_Seoul.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
CCTV_Seoul
# Out:
#       구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0      계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1    종로구   1,772      813      0      0    210    150      1    261     85
# 2    중 구   2,333       16    114     87     77    236    240    372    386
# 3    용산구   2,383       34     71    234    125    221    298    351    125
# 4    성동구   3,602      448    125    212    105    339    310    874    390
# 5    광진구   2,588       35     57    100    187     98     52    675    465
# 6   동대문구   2,497    1,090    146     60     29    111    233    136    197
# 7    중랑구   3,296      302     24    253     88    141    161    162    173
# 8    성북구   3,958       83     78    170    230    323    594    460    867
# 9    강북구   2,462        0      0     24     65    105    243      6    392
# 10   도봉구   1,629       39     22     96    181     79    159    134    222
# ...

# %%
CCTV_Seoul['2020년'].unique()
# Out:
# array(['11,132', '200', '361', '617', '461', '175', '223', '939', '251',
#        '588', '168', '386', '288', '397', '300', '325', '356', '415',
#        '508', '1,213', '419', '331', '420', '942', '235', '614'],
#       dtype=object)

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0] : '구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
CCTV_Seoul['구별'] = CCTV_Seoul['구별'].str.replace(' ','')
CCTV_Seoul['구별']
# Out:
# 0        계
# 1      종로구
# 2       중구
# 3      용산구
# 4      성동구
# 5      광진구
# 6     동대문구
# 7      중랑구
# 8      성북구
# 9      강북구
# 10     도봉구
# 11     노원구
# 12     은평구
# 13    서대문구
# 14     마포구
# 15     양천구
# 16     강서구
# 17     구로구
# 18     금천구
# 19    영등포구
# 20     동작구
# 21     관악구
# 22     서초구
# 23     강남구
# 24     송파구
# 25     강동구
# Name: 구별, dtype: object

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[1] : '소계'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별      소계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2   중구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
CCTV_Seoul.sort_values(by='소계', ascending=True).head(5)
# Out:
#      구별     소계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 10  도봉구  1,629       39    22    96   181    79   159   134   222   198   168
# 1   종로구  1,772      813     0     0   210   150     1   261    85     9   200
# 20  동작구  2,297       41    24    25   503   128   253   271   300   322   419
# 2    중구  2,333       16   114    87    77   236   240   372   386   155   361
# 18  금천구  2,374        0     0   178    80   361   133   196   540   369   508
#
#    2021년
# 10   331
# 1     43
# 20    11
# 2    289
# 18     9

# %%
CCTV_Seoul.sort_values(by='소계', ascending=False).head(5)
# Out:
#      구별      소계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0     계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 23  강남구   6,502      124     77     75    597    840   1310    999    748
# 21  관악구   4,942      428    205    291    513    529    621    687    663
# 17  구로구   4,075      852    216    349    187    268    326    540    488
# 8   성북구   3,958       83     78    170    230    323    594    460    867
#
#      2019년   2020년  2021년
# 0   11,961  11,132  1,608
# 23     789     942      1
# 21     640     331     34
# 17     434     415      0
# 8      714     251    188

# %%
import numpy as np
import pandas as pd

# %%
crime_anal = pd.read_csv('data/CRIME_2020.csv', encoding='euc-kr')
crime_anal.head()
# Out:
#    자치구 살인발생 살인검거  강도발생  강도검거  강간발생  강간검거   절도발생 절도검거   폭력발생   폭력검거
# 0  종로구    9    7     7     9   192   855  1,183  944  1,711  1,528
# 1   중구    2    2     5     6   186   128  1,642  863  1,576  1,324
# 2  용산구    5    3     6     6   230   186  1,111  534  1,617  1,327
# 3  성동구    5    5     3     3   115    98  1,016  565  1,223  1,103
# 4  광진구    2    2     4     4   255   224  1,664  874  1,676  1,407

# %%
crime_anal['강간검거율'] = crime_anal['강간검거']/crime_anal['강간발생']*100
crime_anal['강도검거율'] = crime_anal['강도검거']/crime_anal['강도발생']*100
#crime_anal['살인검거율'] = crime_anal['살인검거']/crime_anal['살인발생']*100
#crime_anal['절도검거율'] = crime_anal['절도검거']/crime_anal['절도발생']*100
#crime_anal['폭력검거율'] = crime_anal['폭력검거']/crime_anal['폭력발생']*100


del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']




crime_anal.head()
# Out:
#    자치구 살인발생 살인검거  강도발생  강도검거  강간발생  강간검거   절도발생 절도검거   폭력발생   폭력검거  \
# 0  종로구    9    7     7     9   192   855  1,183  944  1,711  1,528
# 1   중구    2    2     5     6   186   128  1,642  863  1,576  1,324
# 2  용산구    5    3     6     6   230   186  1,111  534  1,617  1,327
# 3  성동구    5    5     3     3   115    98  1,016  565  1,223  1,103
# 4  광진구    2    2     4     4   255   224  1,664  874  1,676  1,407
#
#         강간검거율       강도검거율
# 0  445.312500  128.571429
# 1   68.817204  120.000000
# 2   80.869565  100.000000
# 3   85.217391  100.000000
# 4   87.843137  100.000000

# %% [markdown]
# 제가 가져온 CRIME_2020 데이터가 이상한점이 많아 교수님이 올려주신
# 02. crime_in_Seoul_include_gu_name.csv로 진행하겠습니다

# %%
crime_anal_police = pd.read_csv('data/02. crime_in_Seoul_include_gu_name.csv', thousands=',')
crime_anal_police.head()
# Out:
#    Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0           0   중부서      2      2      3      2    105     65   1395    477
# 1           1   종로서      3      3      6      5    115     98   1070    413
# 2           2  남대문서      1      0      6      4     65     46   1153    382
# 3           3  서대문서      2      2      5      4    154    124   1812    738
# 4           4   혜화서      3      2      5      4     96     63   1114    424
#
#    폭력 발생  폭력 검거    구별
# 0   1355   1170    중구
# 1   1278   1070   종로구
# 2    869    794    중구
# 3   2056   1711  서대문구
# 4   1015    861   종로구

# %%
crime_anal_raw = pd.read_csv('data/02. crime_in_Seoul_include_gu_name.csv', 
                             index_col=0)

crime_anal = pd.pivot_table(crime_anal_raw, index='구별', aggfunc=np.sum)
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구    349    449     18     21     10     13   1650   3850   3705   4284
# 강동구    123    156      8      6      3      4    789   2366   2248   2712
# 강북구    126    153     13     14      8      7    618   1434   2348   2649
# 관악구    221    320     14     12      8      9    827   2706   2642   3298
# 광진구    220    240     26     14      4      4   1277   3026   2180   2625

# %%
crime_anal['강간검거율'] = crime_anal['강간 검거']/crime_anal['강간 발생']*100
crime_anal['강도검거율'] = crime_anal['강도 검거']/crime_anal['강도 발생']*100
crime_anal['살인검거율'] = crime_anal['살인 검거']/crime_anal['살인 발생']*100
crime_anal['절도검거율'] = crime_anal['절도 검거']/crime_anal['절도 발생']*100
crime_anal['폭력검거율'] = crime_anal['폭력 검거']/crime_anal['폭력 발생']*100

del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']

crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  133.333333   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  114.285714
# 관악구    320     12      9   2706   3298  69.062500  116.666667   88.888889
# 광진구    240     14      4   3026   2625  91.666667  185.714286  100.000000
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  30.561715  80.109157
# 광진구  42.200925  83.047619

# %%
#검거율 100퍼 넘는건 >>100으로 가정
con_list = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

for column in con_list:
    crime_anal.loc[crime_anal[column] > 100, column] = 100
    
crime_anal.head()
# Out:
#      강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구    449     21     13   3850   4284  77.728285   85.714286   76.923077
# 강동구    156      6      4   2366   2712  78.846154  100.000000   75.000000
# 강북구    153     14      7   1434   2649  82.352941   92.857143  100.000000
# 관악구    320     12      9   2706   3298  69.062500  100.000000   88.888889
# 광진구    240     14      4   3026   2625  91.666667  100.000000  100.000000
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 관악구  30.561715  80.109157
# 광진구  42.200925  83.047619

# %%
crime_anal.rename(columns = {'강간 발생':'강간', 
                             '강도 발생':'강도', 
                             '살인 발생':'살인', 
                             '절도 발생':'절도', 
                             '폭력 발생':'폭력'}, inplace=True)
crime_anal.head()
# Out:
#       강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구  449  21  13  3850  4284  77.728285   85.714286   76.923077  42.857143
# 강동구  156   6   4  2366  2712  78.846154  100.000000   75.000000  33.347422
# 강북구  153  14   7  1434  2649  82.352941   92.857143  100.000000  43.096234
# 관악구  320  12   9  2706  3298  69.062500  100.000000   88.888889  30.561715
# 광진구  240  14   4  3026  2625  91.666667  100.000000  100.000000  42.200925
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# 관악구  80.109157
# 광진구  83.047619

# %%
from sklearn import preprocessing

col = ['강간', '강도', '살인', '절도', '폭력']

x = crime_anal[col].values
min_max_scaler = preprocessing.MinMaxScaler()

x_scaled = min_max_scaler.fit_transform(x.astype(float))
crime_anal_norm = pd.DataFrame(x_scaled, columns = col, index = crime_anal.index)

col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_anal_norm[col2] = crime_anal[col2]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 관악구   88.888889  30.561715  80.109157
# 광진구  100.000000  42.200925  83.047619

# %%
CCTV_Seoul.head()
# Out:
#     구별      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
result_CCTV = pd.read_csv('data/CCTV_2020.csv', index_col='구별')
crime_anal_norm['CCTV'] = result_CCTV['2020년']
crime_anal_norm.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-d19b4039403e> in <module>
# ----> 1 result_CCTV = pd.read_csv('data/CCTV_2020.csv', index_col='구별')
#       2 crime_anal_norm['CCTV'] = result_CCTV['2020년']
#       3 crime_anal_norm.head()
#
# ...

# %%
col = ['강간','강도','살인','절도','폭력']
crime_anal_norm['범죄'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  4.472701
# 강동구   75.000000  33.347422  82.890855  1.116551
# 강북구  100.000000  43.096234  88.637222  1.494746
# 관악구   88.888889  30.561715  80.109157  2.613667
# 광진구  100.000000  42.200925  83.047619  2.034438

# %%
col = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619  2.034438  416.915211

# %%
crime_anal_norm
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  \
# 구별
# 강남구   1.000000  0.941176  0.916667  0.953472  0.661386   77.728285
# 강동구   0.155620  0.058824  0.166667  0.445775  0.289667   78.846154
# 강북구   0.146974  0.529412  0.416667  0.126924  0.274769   82.352941
# 관악구   0.628242  0.411765  0.583333  0.562094  0.428234   69.062500
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667
# 구로구   0.515850  0.588235  0.500000  0.435169  0.359423   58.362989
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702
# 노원구   0.273775  0.117647  0.666667  0.386589  0.292268   61.421320
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064
# 동작구   0.527378  0.235294  0.250000  0.274376  0.100024   48.771930
# 마포구   0.553314  0.529412  0.500000  0.510434  0.353748   84.013605
# 서대문구  0.149856  0.000000  0.000000  0.256244  0.134547   80.519481
# ...

# %% [markdown]
# ## 4. 범죄 데이터 시각화(seaborn)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  0.953472  0.661386  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.445775  0.289667  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.126924  0.274769  82.352941   92.857143
# 관악구  0.628242  0.411765  0.583333  0.562094  0.428234  69.062500  100.000000
# 광진구  0.397695  0.529412  0.166667  0.671570  0.269094  91.666667  100.000000
#
#           살인검거율      절도검거율      폭력검거율        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  4.472701  369.707384
# 강동구   75.000000  33.347422  82.890855  1.116551  370.084431
# 강북구  100.000000  43.096234  88.637222  1.494746  406.943540
# 관악구   88.888889  30.561715  80.109157  2.613667  368.622261
# 광진구  100.000000  42.200925  83.047619  2.034438  416.915211

# %%
sns.pairplot(crime_anal_norm, vars=["강도", "살인", "폭력"], kind='reg', size=3)
plt.show()
# Out:
# C:\Users\dohoo\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거'] / tmp_max * 100
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  강도검거율  \
# 구별
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000  100.0
# 금천구   0.141210  0.058824  0.083333  0.172426  0.134074   80.794702  100.0
# 광진구   0.397695  0.529412  0.166667  0.671570  0.269094   91.666667  100.0
# 동대문구  0.204611  0.470588  0.250000  0.314061  0.250887   84.393064  100.0
# 용산구   0.265130  0.529412  0.250000  0.169004  0.133128   89.175258  100.0
#
#       살인검거율      절도검거율      폭력검거율        범죄          검거
# 구별
# 도봉구   100.0  44.967074  87.626093  0.318627  100.000000
# 금천구   100.0  56.668794  86.465433  0.589867   97.997139
# 광진구   100.0  42.200925  83.047619  2.034438   96.375820
# 동대문구  100.0  41.090358  87.401884  1.490147   95.444250
# 용산구   100.0  37.700706  83.121951  1.346674   94.776790

# %%
target_col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)

plt.figure(figsize = (10,10))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', 
                    linewidths=.5, cmap='RdPu')
plt.title('범죄 검거 비율 (정규화된 검거의 합으로 정렬)')
plt.show()

# %%
target_col = ['강간', '강도', '살인', '절도', '폭력', '범죄']

crime_anal_norm['범죄'] = crime_anal_norm['범죄'] / 5
crime_anal_norm_sort = crime_anal_norm.sort_values(by='범죄', ascending=False)

plt.figure(figsize = (10,10))
sns.heatmap(crime_anal_norm_sort[target_col], annot=True, fmt='f', linewidths=.5,
                       cmap='RdPu')
plt.title('범죄비율 (정규화된 발생 건수로 정렬)')
plt.show()
